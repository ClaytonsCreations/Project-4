# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from pathlib import Path
from sklearn.preprocessing import StandardScaler

# %%
# Loading data
file_path = Path("Resources/Superstore_US.csv")
Superstore_US = pd.read_csv(file_path)
Superstore_US.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
Superstore_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
Superstore_US['Quantity'] = Superstore_US['Quantity'].astype(float)

# %%
Superstore_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
import sys
sys.setrecursionlimit(9999)

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 9999

# %%
Superstore_US = Superstore_US.drop(columns=['City', 'Postal Code', 'Product ID'])
Superstore_US
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 2          3  CA-2013-138688   6/13/2013   6/17/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422   1/22/2011   1/24/2011    Second Class
# 9990    9991  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9991    9992  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9992    9993  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9993    9994  CA-2014-119914    5/5/2014   5/10/2014    Second Class
#
#      Customer ID     Customer Name    Segment        Country       State  \
# ...

# %%
Superstore_US['Unit Price'] = Superstore_US['Sales']/Superstore_US['Quantity']

# %%
Superstore_US
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 2          3  CA-2013-138688   6/13/2013   6/17/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422   1/22/2011   1/24/2011    Second Class
# 9990    9991  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9991    9992  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9992    9993  CA-2014-121258   2/27/2014    3/4/2014  Standard Class
# 9993    9994  CA-2014-119914    5/5/2014   5/10/2014    Second Class
#
#      Customer ID     Customer Name    Segment        Country       State  \
# ...

# %%
# Loading data
file_path = Path("Resources/Superstore_CAN.csv")
Superstore_CAN = pd.read_csv(file_path)
Superstore_CAN
# Out:
#       Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3  10/13/2010            Low               6    261.5400
# 1         49       293   10/1/2012           High              49  10123.0200
# 2         50       293   10/1/2012           High              27    244.5700
# 3         80       483   7/10/2011           High              30   4965.7595
# 4         85       515   8/28/2010  Not Specified              19    394.2700
# ...      ...       ...         ...            ...             ...         ...
# 8394    7765     55558    8/9/2010         Medium               8   1294.0400
# 8395    7766     55558    8/9/2010         Medium              23    392.5700
# 8396    7906     56550    4/8/2011  Not Specified              37    823.7800
# 8397    7907     56550    4/8/2011  Not Specified               8    469.8375
# 8398    7914     56581    2/8/2009           High              20   2026.0100
#
# ...

# %%
Superstore_CAN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8399 non-null   int64
#  1   Order ID              8399 non-null   int64
#  2   Order Date            8399 non-null   object
#  3   Order Priority        8399 non-null   object
#  4   Order Quantity        8399 non-null   int64
#  5   Sales                 8399 non-null   float64
#  6   Discount              8399 non-null   float64
#  7   Ship Mode             8399 non-null   object
#  8   Profit                8399 non-null   float64
#  9   Unit Price            8399 non-null   float64
#  10  Shipping Cost         8399 non-null   float64
#  11  Customer Name         8399 non-null   object
#  12  Province              8399 non-null   object
#  13  Region                8399 non-null   object
#  14  Customer Segment      8399 non-null   object
# ...

# %%
Superstore_CAN = Superstore_CAN.drop(columns=['Shipping Cost', 'Product Container', 'Product Base Margin'])
Superstore_CAN
# Out:
#       Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3  10/13/2010            Low               6    261.5400
# 1         49       293   10/1/2012           High              49  10123.0200
# 2         50       293   10/1/2012           High              27    244.5700
# 3         80       483   7/10/2011           High              30   4965.7595
# 4         85       515   8/28/2010  Not Specified              19    394.2700
# ...      ...       ...         ...            ...             ...         ...
# 8394    7765     55558    8/9/2010         Medium               8   1294.0400
# 8395    7766     55558    8/9/2010         Medium              23    392.5700
# 8396    7906     56550    4/8/2011  Not Specified              37    823.7800
# 8397    7907     56550    4/8/2011  Not Specified               8    469.8375
# 8398    7914     56581    2/8/2009           High              20   2026.0100
#
# ...

# %%
Superstore_US.to_csv('Superstore_US_Clean.csv')

# %%
Superstore_CAN.to_csv('Superstore_CAN_Clean.csv')
